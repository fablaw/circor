# %% [markdown]
# # further preprocessing

# %%
import pandas as pd
import numpy as np

file='../raw_data/1.0.3/training_data.csv'
df=pd.read_csv(file)
df.head()
# Out:
#    Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0        2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1        9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 2        9983          AV+PV+TV+MV  Child    Male   115.0    19.1
# 3       13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4       14241          AV+PV+TV+MV  Child    Male    87.0    11.2
#
#    Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0             False   Absent              NaN                   NaN  ...
# 1             False  Present      AV+MV+PV+TV                    TV  ...
# 2             False  Unknown              NaN                   NaN  ...
# 3             False  Present               TV                    TV  ...
# 4             False  Present      AV+MV+PV+TV                    PV  ...
#
#   Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                   NaN                     NaN                     NaN
# 1                  High                   Harsh                     NaN
# 2                   NaN                     NaN                     NaN
# 3                   Low                 Blowing                     NaN
# 4                   Low                   Harsh                     NaN
#
#   Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                    NaN                      NaN                    NaN
# 1                    NaN                      NaN                    NaN
# 2                    NaN                      NaN                    NaN
# 3                    NaN                      NaN                    NaN
# 4                    NaN                      NaN                    NaN
#
#   Diastolic murmur quality   Outcome Campaign Additional ID
# 0                      NaN  Abnormal   CC2015           NaN
# 1                      NaN  Abnormal   CC2015           NaN
# 2                      NaN  Abnormal   CC2015           NaN
# 3                      NaN  Abnormal   CC2015           NaN
# 4                      NaN  Abnormal   CC2015           NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# from scipy.signal import butter, lfilter
#
# fs = 4000.0
# lowcut = 15.0
# highcut = 150.0
#
# def butter_bandpass(lowcut, highcut, fs, order=5):
#     return butter(order, [lowcut, highcut], fs=fs, btype='band')
#
# def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
#     b, a = butter_bandpass(lowcut, highcut, fs, order=order)
#     y = lfilter(b, a, data)
#     return y

# %% [markdown]
# import glob
# for f in glob.glob(f'/Users/fabianlaw/code/fablaw/circor/raw_data/1.0.3/tmp_dir_2/*.npy'):
#     x = np.load(f)[0:12000]
#     y = butter_bandpass_filter(x, lowcut, highcut, fs, order=6)
#     y_1=y[~np.isnan(y)]
#     y_2=y_1/np.abs(np.amax(y_1))
#
#     c=(''.join(f.rsplit('.npy',1))).split('/')
#     output='/Users/fabianlaw/code/fablaw/circor/raw_data/1.0.3/filtered_2/'+c[-1]+'.npy'
#     np.save(output, y_2)

# %%
def drop_duplicates(data):
    doublon=data[['Patient ID','Additional ID']].dropna()
    liste_couple=[]
    for i in range(len(doublon)):
        min_id=min(doublon.iloc[i]['Patient ID'],doublon.iloc[i]['Additional ID'])
        max_id=max(doublon.iloc[i]['Patient ID'],doublon.iloc[i]['Additional ID'])
        if [min_id,max_id] not in liste_couple:
            liste_couple.append([min_id,max_id])
    list_id_drop=np.array(liste_couple)[:,1]
    data_drop_dup=data[~data['Patient ID'].isin(list_id_drop)]
    return data_drop_dup

# %%
df_drop_dup=drop_duplicates(df)
df_drop_dup
# Out:
#      Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0          2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1          9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 2          9983          AV+PV+TV+MV  Child    Male   115.0    19.1
# 3         13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4         14241          AV+PV+TV+MV  Child    Male    87.0    11.2
# ..          ...                  ...    ...     ...     ...     ...
# 937       85340          AV+PV+TV+MV  Child    Male   105.0    16.6
# 938       85341          AV+PV+TV+MV  Child    Male    92.0    15.2
# 939       85343          AV+PV+TV+MV  Child  Female    97.0    13.5
# 940       85345                AV+PV  Child  Female   132.0    38.1
# 941       85349             AV+PV+TV    NaN  Female     NaN     NaN
#
#      Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0               False   Absent              NaN                   NaN  ...
# 1               False  Present      AV+MV+PV+TV                    TV  ...
# 2               False  Unknown              NaN                   NaN  ...
# 3               False  Present               TV                    TV  ...
# 4               False  Present      AV+MV+PV+TV                    PV  ...
# ..                ...      ...              ...                   ...  ...
# 937             False   Absent              NaN                   NaN  ...
# 938             False   Absent              NaN                   NaN  ...
# 939             False  Present            MV+TV                    TV  ...
# 940             False   Absent              NaN                   NaN  ...
# 941              True   Absent              NaN                   NaN  ...
#
#     Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                     NaN                     NaN                     NaN
# 1                    High                   Harsh                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     Low                 Blowing                     NaN
# 4                     Low                   Harsh                     NaN
# ..                    ...                     ...                     ...
# 937                   NaN                     NaN                     NaN
# 938                   NaN                     NaN                     NaN
# 939                   Low                 Blowing                     NaN
# 940                   NaN                     NaN                     NaN
# 941                   NaN                     NaN                     NaN
#
#     Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 2                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
# ..                     ...                      ...                    ...
# 937                    NaN                      NaN                    NaN
# 938                    NaN                      NaN                    NaN
# 939                    NaN                      NaN                    NaN
# 940                    NaN                      NaN                    NaN
# 941                    NaN                      NaN                    NaN
#
#     Diastolic murmur quality   Outcome Campaign Additional ID
# 0                        NaN  Abnormal   CC2015           NaN
# 1                        NaN  Abnormal   CC2015           NaN
# 2                        NaN  Abnormal   CC2015           NaN
# 3                        NaN  Abnormal   CC2015           NaN
# 4                        NaN  Abnormal   CC2015           NaN
# ..                       ...       ...      ...           ...
# 937                      NaN    Normal   CC2015           NaN
# 938                      NaN    Normal   CC2015           NaN
# 939                      NaN  Abnormal   CC2015           NaN
# 940                      NaN    Normal   CC2015           NaN
# 941                      NaN    Normal   CC2015           NaN
#
# [872 rows x 23 columns]

# %%
ls=[]
for i in df_drop_dup.index:
    r=df_drop_dup.loc[i, 'Recording locations:'].split('+')
    l=np.random.choice(r)
    ls.append(l)

# %%
df_new=pd.DataFrame({'Patient_id': df_drop_dup['Patient ID'], 
                     'select': ls,
                     'audible': df_drop_dup['Most audible location']
                    })
df_new
# Out:
#      Patient_id select audible
# 0          2530     PV     NaN
# 1          9979     TV      TV
# 2          9983     AV     NaN
# 3         13918     MV      TV
# 4         14241     MV      PV
# ..          ...    ...     ...
# 937       85340     PV     NaN
# 938       85341     PV     NaN
# 939       85343     AV      TV
# 940       85345     AV     NaN
# 941       85349     AV     NaN
#
# [872 rows x 3 columns]

# %%
df_new.audible.fillna(df_new.select, inplace=True)
df_new
# Out:
#      Patient_id select audible
# 0          2530     PV      PV
# 1          9979     TV      TV
# 2          9983     AV      AV
# 3         13918     MV      TV
# 4         14241     MV      PV
# ..          ...    ...     ...
# 937       85340     PV      PV
# 938       85341     PV      PV
# 939       85343     AV      TV
# 940       85345     AV      AV
# 941       85349     AV      AV
#
# [872 rows x 3 columns]

# %%
def load_npy(a,b):
    file=f"../raw_data/1.0.3/filtered_2/{a}_{b}.npy"
    v=np.load(file)[0:6000]
    return v

la=[]
for i in df_new.index:
    la.append(load_npy(df_new.Patient_id[i], df_new.audible[i]))

# %%
X_rec=np.expand_dims(la, axis=-1)
X_rec.shape
# Out:
# (872, 6000, 1)

# %%
y_rec=df_drop_dup.Outcome.map({'Abnormal': 1, 'Normal': 0})
y_rec.shape
# Out:
# (872,)

# %%
from tensorflow.keras.layers import Masking, LSTM, Conv1D, Dense, MaxPool1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Recall

# %%
from sklearn.model_selection import train_test_split

X_rec_train, X_rec_test, y_rec_train, y_rec_test= train_test_split(X_rec, y_rec, test_size=0.3, random_state=1)

# %%
def create_model():
    model_rec=Sequential()
    model_rec.add(Masking(mask_value=-10, input_shape=(6000,1)))
    model_rec.add(Conv1D(24, kernel_size=15, strides=2, activation='relu'))
    model_rec.add(MaxPool1D(3, strides=2))
    model_rec.add(Conv1D(48, kernel_size=7, strides=2, activation='relu'))
    model_rec.add(MaxPool1D(3, strides=2))
    model_rec.add(Conv1D(96, kernel_size=7, strides=2, activation='relu'))
    model_rec.add(MaxPool1D(3, strides=2))
    model_rec.add(LSTM(units=20, return_sequences=True))
    model_rec.add(LSTM(units=20, return_sequences=True))
    model_rec.add(LSTM(units=20, return_sequences=True))
    model_rec.add(LSTM(units=20, return_sequences=True))
    model_rec.add(LSTM(units=20, return_sequences=False))
    model_rec.add(Dense(1, activation='sigmoid'))
    
    return model_rec

# %%
adam=Adam(learning_rate=0.00001)
model_1=create_model()
model_1.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy', Recall()])

# %%
es=EarlyStopping(patience=30, restore_best_weights=True, monitor='val_recall')
history_1=model_1.fit(X_rec_train, y_rec_train, batch_size=16, epochs=150, validation_split=0.2, callbacks=[es])
# Out:
# Epoch 1/150
# /Users/fabianlaw/.pyenv/versions/3.10.6/envs/circor/lib/python3.10/site-packages/keras/engine/data_adapter.py:1699: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 2022-12-01 11:23:35.758067: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 8/8 [==============================] - 5s 215ms/step - loss: 0.6934 - accuracy: 0.5041 - recall: 0.5171 - val_loss: 0.6940 - val_accuracy: 0.5000 - val_recall: 0.4906
# Epoch 2/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6934 - accuracy: 0.5041 - recall: 0.5171 - val_loss: 0.6939 - val_accuracy: 0.5000 - val_recall: 0.4906
# Epoch 3/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6933 - accuracy: 0.5041 - recall: 0.5171 - val_loss: 0.6936 - val_accuracy: 0.5000 - val_recall: 0.4906
# Epoch 4/150
# 8/8 [==============================] - 1s 101ms/step - loss: 0.6933 - accuracy: 0.5041 - recall: 0.5171 - val_loss: 0.6935 - val_accuracy: 0.5000 - val_recall: 0.4906
# Epoch 5/150
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6934 - accuracy: 0.5041 - recall: 0.5171 - val_loss: 0.6933 - val_accuracy: 0.5000 - val_recall: 0.4906
# Epoch 6/150
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6932 - accuracy: 0.5061 - recall: 0.5171 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_recall: 0.4906
# Epoch 7/150
# 8/8 [==============================] - 1s 99ms/step - loss: 0.6932 - accuracy: 0.5102 - recall: 0.5085 - val_loss: 0.6931 - val_accuracy: 0.4918 - val_recall: 0.4717
# Epoch 8/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6931 - accuracy: 0.5225 - recall: 0.2350 - val_loss: 0.6929 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 9/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6931 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6927 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 10/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6931 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6926 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 11/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6931 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6926 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 12/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6926 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 13/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6926 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 14/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6925 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 15/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6925 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 16/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6925 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 17/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6924 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 18/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6924 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 19/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6923 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 20/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6923 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 21/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6930 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6922 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 22/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6922 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 23/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6921 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 24/150
# 8/8 [==============================] - 1s 103ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6921 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 25/150
# 8/8 [==============================] - 1s 110ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6921 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 26/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6920 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 27/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6920 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 28/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6920 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 29/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6920 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 30/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6920 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 31/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6919 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 32/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6919 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 33/150
# 8/8 [==============================] - 1s 107ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6919 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 34/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6919 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 35/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6918 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 36/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.6929 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6918 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 37/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6928 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6918 - val_accuracy: 0.5656 - val_recall: 0.0000e+00
# Epoch 38/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.6928 - accuracy: 0.5205 - recall: 0.0000e+00 - val_loss: 0.6918 - val_accuracy: 0.5656 - val_recall: 0.0000e+00

# %%
es.best_epoch
# Out:
# 7

# %%
model_1.evaluate(X_rec_test, y_rec_test)
# Out:
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6929 - accuracy: 0.5725 - recall: 0.0000e+00
# [0.6928632855415344, 0.572519063949585, 0.0]

# %%
def plot_loss_recall(history):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,4))
    ax1.plot(history.history['loss'])
    ax1.plot(history.history['val_loss'])
    ax1.set_title('Model loss')
    ax1.set_ylabel('Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylim(ymin=0, ymax=1)
    ax1.legend(['Train', 'Validation'], loc='best')
    ax1.grid(axis="x",linewidth=0.5)
    ax1.grid(axis="y",linewidth=0.5)    

    
    ax2.plot(history.history['recall'])
    ax2.plot(history.history['val_recall'])
    ax2.set_title('RECALL')
    ax2.set_ylabel('Recall')
    ax2.set_xlabel('Epoch')
    ax2.set_ylim(ymin=0, ymax=1)
    ax2.legend(['Train', 'Validation'], loc='best')
    ax2.grid(axis="x",linewidth=0.5)
    ax2.grid(axis="y",linewidth=0.5)    

    plt.show()

# %%
import matplotlib.pyplot as plt
plot_loss_recall(history_1)
