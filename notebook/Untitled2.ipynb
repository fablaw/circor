# %%
import pandas as pd
import numpy as np

file='../raw_data/1.0.3/training_data.csv'
df=pd.read_csv(file)
df.head()
# Out:
#    Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0        2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1        9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 2        9983          AV+PV+TV+MV  Child    Male   115.0    19.1
# 3       13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4       14241          AV+PV+TV+MV  Child    Male    87.0    11.2
#
#    Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0             False   Absent              NaN                   NaN  ...
# 1             False  Present      AV+MV+PV+TV                    TV  ...
# 2             False  Unknown              NaN                   NaN  ...
# 3             False  Present               TV                    TV  ...
# 4             False  Present      AV+MV+PV+TV                    PV  ...
#
#   Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                   NaN                     NaN                     NaN
# 1                  High                   Harsh                     NaN
# 2                   NaN                     NaN                     NaN
# 3                   Low                 Blowing                     NaN
# 4                   Low                   Harsh                     NaN
#
#   Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                    NaN                      NaN                    NaN
# 1                    NaN                      NaN                    NaN
# 2                    NaN                      NaN                    NaN
# 3                    NaN                      NaN                    NaN
# 4                    NaN                      NaN                    NaN
#
#   Diastolic murmur quality   Outcome Campaign Additional ID
# 0                      NaN  Abnormal   CC2015           NaN
# 1                      NaN  Abnormal   CC2015           NaN
# 2                      NaN  Abnormal   CC2015           NaN
# 3                      NaN  Abnormal   CC2015           NaN
# 4                      NaN  Abnormal   CC2015           NaN
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (942, 23)

# %%
df=df[~df['Murmur'].isin(['Unknown'])]
df
# Out:
#      Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0          2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1          9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 3         13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4         14241          AV+PV+TV+MV  Child    Male    87.0    11.2
# 5         14998          AV+PV+TV+MV  Child    Male     NaN     NaN
# ..          ...                  ...    ...     ...     ...     ...
# 937       85340          AV+PV+TV+MV  Child    Male   105.0    16.6
# 938       85341          AV+PV+TV+MV  Child    Male    92.0    15.2
# 939       85343          AV+PV+TV+MV  Child  Female    97.0    13.5
# 940       85345                AV+PV  Child  Female   132.0    38.1
# 941       85349             AV+PV+TV    NaN  Female     NaN     NaN
#
#      Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0               False   Absent              NaN                   NaN  ...
# 1               False  Present      AV+MV+PV+TV                    TV  ...
# 3               False  Present               TV                    TV  ...
# 4               False  Present      AV+MV+PV+TV                    PV  ...
# 5               False   Absent              NaN                   NaN  ...
# ..                ...      ...              ...                   ...  ...
# 937             False   Absent              NaN                   NaN  ...
# 938             False   Absent              NaN                   NaN  ...
# 939             False  Present            MV+TV                    TV  ...
# 940             False   Absent              NaN                   NaN  ...
# 941              True   Absent              NaN                   NaN  ...
#
#     Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                     NaN                     NaN                     NaN
# 1                    High                   Harsh                     NaN
# 3                     Low                 Blowing                     NaN
# 4                     Low                   Harsh                     NaN
# 5                     NaN                     NaN                     NaN
# ..                    ...                     ...                     ...
# 937                   NaN                     NaN                     NaN
# 938                   NaN                     NaN                     NaN
# 939                   Low                 Blowing                     NaN
# 940                   NaN                     NaN                     NaN
# 941                   NaN                     NaN                     NaN
#
#     Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
# 5                      NaN                      NaN                    NaN
# ..                     ...                      ...                    ...
# 937                    NaN                      NaN                    NaN
# 938                    NaN                      NaN                    NaN
# 939                    NaN                      NaN                    NaN
# 940                    NaN                      NaN                    NaN
# 941                    NaN                      NaN                    NaN
#
#     Diastolic murmur quality   Outcome Campaign Additional ID
# 0                        NaN  Abnormal   CC2015           NaN
# 1                        NaN  Abnormal   CC2015           NaN
# 3                        NaN  Abnormal   CC2015           NaN
# 4                        NaN  Abnormal   CC2015           NaN
# 5                        NaN  Abnormal   CC2015           NaN
# ..                       ...       ...      ...           ...
# 937                      NaN    Normal   CC2015           NaN
# 938                      NaN    Normal   CC2015           NaN
# 939                      NaN  Abnormal   CC2015           NaN
# 940                      NaN    Normal   CC2015           NaN
# 941                      NaN    Normal   CC2015           NaN
#
# [874 rows x 23 columns]

# %%
def drop_duplicates(data: pd.DataFrame) -> pd.DataFrame:
    """Drop all patients who have an Additional ID"""
    doublon=data[['Patient ID','Additional ID']].dropna()
    liste_couple=[]
    for i in range(len(doublon)):
        min_id=min(doublon.iloc[i]['Patient ID'],doublon.iloc[i]['Additional ID'])
        max_id=max(doublon.iloc[i]['Patient ID'],doublon.iloc[i]['Additional ID'])
        if [min_id,max_id] not in liste_couple:
            liste_couple.append([min_id,max_id])
    list_id_drop=np.array(liste_couple)[:,1]
    data_drop_dup=data[~data['Patient ID'].isin(list_id_drop)]
    return data_drop_dup

# %%
dup=drop_duplicates(df)
dup
# Out:
#      Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0          2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1          9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 3         13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4         14241          AV+PV+TV+MV  Child    Male    87.0    11.2
# 5         14998          AV+PV+TV+MV  Child    Male     NaN     NaN
# ..          ...                  ...    ...     ...     ...     ...
# 937       85340          AV+PV+TV+MV  Child    Male   105.0    16.6
# 938       85341          AV+PV+TV+MV  Child    Male    92.0    15.2
# 939       85343          AV+PV+TV+MV  Child  Female    97.0    13.5
# 940       85345                AV+PV  Child  Female   132.0    38.1
# 941       85349             AV+PV+TV    NaN  Female     NaN     NaN
#
#      Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0               False   Absent              NaN                   NaN  ...
# 1               False  Present      AV+MV+PV+TV                    TV  ...
# 3               False  Present               TV                    TV  ...
# 4               False  Present      AV+MV+PV+TV                    PV  ...
# 5               False   Absent              NaN                   NaN  ...
# ..                ...      ...              ...                   ...  ...
# 937             False   Absent              NaN                   NaN  ...
# 938             False   Absent              NaN                   NaN  ...
# 939             False  Present            MV+TV                    TV  ...
# 940             False   Absent              NaN                   NaN  ...
# 941              True   Absent              NaN                   NaN  ...
#
#     Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                     NaN                     NaN                     NaN
# 1                    High                   Harsh                     NaN
# 3                     Low                 Blowing                     NaN
# 4                     Low                   Harsh                     NaN
# 5                     NaN                     NaN                     NaN
# ..                    ...                     ...                     ...
# 937                   NaN                     NaN                     NaN
# 938                   NaN                     NaN                     NaN
# 939                   Low                 Blowing                     NaN
# 940                   NaN                     NaN                     NaN
# 941                   NaN                     NaN                     NaN
#
#     Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
# 5                      NaN                      NaN                    NaN
# ..                     ...                      ...                    ...
# 937                    NaN                      NaN                    NaN
# 938                    NaN                      NaN                    NaN
# 939                    NaN                      NaN                    NaN
# 940                    NaN                      NaN                    NaN
# 941                    NaN                      NaN                    NaN
#
#     Diastolic murmur quality   Outcome Campaign Additional ID
# 0                        NaN  Abnormal   CC2015           NaN
# 1                        NaN  Abnormal   CC2015           NaN
# 3                        NaN  Abnormal   CC2015           NaN
# 4                        NaN  Abnormal   CC2015           NaN
# 5                        NaN  Abnormal   CC2015           NaN
# ..                       ...       ...      ...           ...
# 937                      NaN    Normal   CC2015           NaN
# 938                      NaN    Normal   CC2015           NaN
# 939                      NaN  Abnormal   CC2015           NaN
# 940                      NaN    Normal   CC2015           NaN
# 941                      NaN    Normal   CC2015           NaN
#
# [812 rows x 23 columns]

# %%
duplica=df[df['Additional ID'].isna()]
duplica
# Out:
#      Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0          2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1          9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 3         13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4         14241          AV+PV+TV+MV  Child    Male    87.0    11.2
# 5         14998          AV+PV+TV+MV  Child    Male     NaN     NaN
# ..          ...                  ...    ...     ...     ...     ...
# 937       85340          AV+PV+TV+MV  Child    Male   105.0    16.6
# 938       85341          AV+PV+TV+MV  Child    Male    92.0    15.2
# 939       85343          AV+PV+TV+MV  Child  Female    97.0    13.5
# 940       85345                AV+PV  Child  Female   132.0    38.1
# 941       85349             AV+PV+TV    NaN  Female     NaN     NaN
#
#      Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0               False   Absent              NaN                   NaN  ...
# 1               False  Present      AV+MV+PV+TV                    TV  ...
# 3               False  Present               TV                    TV  ...
# 4               False  Present      AV+MV+PV+TV                    PV  ...
# 5               False   Absent              NaN                   NaN  ...
# ..                ...      ...              ...                   ...  ...
# 937             False   Absent              NaN                   NaN  ...
# 938             False   Absent              NaN                   NaN  ...
# 939             False  Present            MV+TV                    TV  ...
# 940             False   Absent              NaN                   NaN  ...
# 941              True   Absent              NaN                   NaN  ...
#
#     Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                     NaN                     NaN                     NaN
# 1                    High                   Harsh                     NaN
# 3                     Low                 Blowing                     NaN
# 4                     Low                   Harsh                     NaN
# 5                     NaN                     NaN                     NaN
# ..                    ...                     ...                     ...
# 937                   NaN                     NaN                     NaN
# 938                   NaN                     NaN                     NaN
# 939                   Low                 Blowing                     NaN
# 940                   NaN                     NaN                     NaN
# 941                   NaN                     NaN                     NaN
#
#     Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
# 5                      NaN                      NaN                    NaN
# ..                     ...                      ...                    ...
# 937                    NaN                      NaN                    NaN
# 938                    NaN                      NaN                    NaN
# 939                    NaN                      NaN                    NaN
# 940                    NaN                      NaN                    NaN
# 941                    NaN                      NaN                    NaN
#
#     Diastolic murmur quality   Outcome Campaign Additional ID
# 0                        NaN  Abnormal   CC2015           NaN
# 1                        NaN  Abnormal   CC2015           NaN
# 3                        NaN  Abnormal   CC2015           NaN
# 4                        NaN  Abnormal   CC2015           NaN
# 5                        NaN  Abnormal   CC2015           NaN
# ..                       ...       ...      ...           ...
# 937                      NaN    Normal   CC2015           NaN
# 938                      NaN    Normal   CC2015           NaN
# 939                      NaN  Abnormal   CC2015           NaN
# 940                      NaN    Normal   CC2015           NaN
# 941                      NaN    Normal   CC2015           NaN
#
# [747 rows x 23 columns]

# %%
duplica_1=duplica[duplica['Recording locations:']=='AV+PV+TV+MV']
duplica_1
# Out:
#      Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0          2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1          9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 3         13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4         14241          AV+PV+TV+MV  Child    Male    87.0    11.2
# 5         14998          AV+PV+TV+MV  Child    Male     NaN     NaN
# ..          ...                  ...    ...     ...     ...     ...
# 934       85337          AV+PV+TV+MV  Child    Male   130.0    27.3
# 935       85338          AV+PV+TV+MV    NaN  Female     NaN     NaN
# 937       85340          AV+PV+TV+MV  Child    Male   105.0    16.6
# 938       85341          AV+PV+TV+MV  Child    Male    92.0    15.2
# 939       85343          AV+PV+TV+MV  Child  Female    97.0    13.5
#
#      Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0               False   Absent              NaN                   NaN  ...
# 1               False  Present      AV+MV+PV+TV                    TV  ...
# 3               False  Present               TV                    TV  ...
# 4               False  Present      AV+MV+PV+TV                    PV  ...
# 5               False   Absent              NaN                   NaN  ...
# ..                ...      ...              ...                   ...  ...
# 934             False   Absent              NaN                   NaN  ...
# 935              True   Absent              NaN                   NaN  ...
# 937             False   Absent              NaN                   NaN  ...
# 938             False   Absent              NaN                   NaN  ...
# 939             False  Present            MV+TV                    TV  ...
#
#     Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                     NaN                     NaN                     NaN
# 1                    High                   Harsh                     NaN
# 3                     Low                 Blowing                     NaN
# 4                     Low                   Harsh                     NaN
# 5                     NaN                     NaN                     NaN
# ..                    ...                     ...                     ...
# 934                   NaN                     NaN                     NaN
# 935                   NaN                     NaN                     NaN
# 937                   NaN                     NaN                     NaN
# 938                   NaN                     NaN                     NaN
# 939                   Low                 Blowing                     NaN
#
#     Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
# 5                      NaN                      NaN                    NaN
# ..                     ...                      ...                    ...
# 934                    NaN                      NaN                    NaN
# 935                    NaN                      NaN                    NaN
# 937                    NaN                      NaN                    NaN
# 938                    NaN                      NaN                    NaN
# 939                    NaN                      NaN                    NaN
#
#     Diastolic murmur quality   Outcome Campaign Additional ID
# 0                        NaN  Abnormal   CC2015           NaN
# 1                        NaN  Abnormal   CC2015           NaN
# 3                        NaN  Abnormal   CC2015           NaN
# 4                        NaN  Abnormal   CC2015           NaN
# 5                        NaN  Abnormal   CC2015           NaN
# ..                       ...       ...      ...           ...
# 934                      NaN    Normal   CC2015           NaN
# 935                      NaN    Normal   CC2015           NaN
# 937                      NaN    Normal   CC2015           NaN
# 938                      NaN    Normal   CC2015           NaN
# 939                      NaN  Abnormal   CC2015           NaN
#
# [488 rows x 23 columns]

# %%
duplica_2=dup[dup['Recording locations:']=='AV+PV+TV+MV']
duplica_2
# Out:
#      Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0          2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1          9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 3         13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4         14241          AV+PV+TV+MV  Child    Male    87.0    11.2
# 5         14998          AV+PV+TV+MV  Child    Male     NaN     NaN
# ..          ...                  ...    ...     ...     ...     ...
# 934       85337          AV+PV+TV+MV  Child    Male   130.0    27.3
# 935       85338          AV+PV+TV+MV    NaN  Female     NaN     NaN
# 937       85340          AV+PV+TV+MV  Child    Male   105.0    16.6
# 938       85341          AV+PV+TV+MV  Child    Male    92.0    15.2
# 939       85343          AV+PV+TV+MV  Child  Female    97.0    13.5
#
#      Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0               False   Absent              NaN                   NaN  ...
# 1               False  Present      AV+MV+PV+TV                    TV  ...
# 3               False  Present               TV                    TV  ...
# 4               False  Present      AV+MV+PV+TV                    PV  ...
# 5               False   Absent              NaN                   NaN  ...
# ..                ...      ...              ...                   ...  ...
# 934             False   Absent              NaN                   NaN  ...
# 935              True   Absent              NaN                   NaN  ...
# 937             False   Absent              NaN                   NaN  ...
# 938             False   Absent              NaN                   NaN  ...
# 939             False  Present            MV+TV                    TV  ...
#
#     Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# 0                     NaN                     NaN                     NaN
# 1                    High                   Harsh                     NaN
# 3                     Low                 Blowing                     NaN
# 4                     Low                   Harsh                     NaN
# 5                     NaN                     NaN                     NaN
# ..                    ...                     ...                     ...
# 934                   NaN                     NaN                     NaN
# 935                   NaN                     NaN                     NaN
# 937                   NaN                     NaN                     NaN
# 938                   NaN                     NaN                     NaN
# 939                   Low                 Blowing                     NaN
#
#     Diastolic murmur shape Diastolic murmur grading Diastolic murmur pitch  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
# 5                      NaN                      NaN                    NaN
# ..                     ...                      ...                    ...
# 934                    NaN                      NaN                    NaN
# 935                    NaN                      NaN                    NaN
# 937                    NaN                      NaN                    NaN
# 938                    NaN                      NaN                    NaN
# 939                    NaN                      NaN                    NaN
#
#     Diastolic murmur quality   Outcome Campaign Additional ID
# 0                        NaN  Abnormal   CC2015           NaN
# 1                        NaN  Abnormal   CC2015           NaN
# 3                        NaN  Abnormal   CC2015           NaN
# 4                        NaN  Abnormal   CC2015           NaN
# 5                        NaN  Abnormal   CC2015           NaN
# ..                       ...       ...      ...           ...
# 934                      NaN    Normal   CC2015           NaN
# 935                      NaN    Normal   CC2015           NaN
# 937                      NaN    Normal   CC2015           NaN
# 938                      NaN    Normal   CC2015           NaN
# 939                      NaN  Abnormal   CC2015           NaN
#
# [521 rows x 23 columns]

# %%
def select_1_recording(df: pd.DataFrame) -> pd.DataFrame:
    """select one recording: either the one where the murmur is most audible or random one"""
    random_rec=[]
    for ind in df.index:
        rec=df.loc[ind, 'Recording locations:'].split('+')
        location=np.random.choice(rec)
        random_rec.append(location)
    #construct new dataframe out of cleaned dataframe
    
    df_new=pd.DataFrame({'patient_id': df['Patient ID'],
                         'select': random_rec,
                         'audible': df['Most audible location'],
                         'outcome': df.Outcome
                        })
    
    df_new.audible.fillna(df_new.select, inplace=True)
    
    return df_new

# %%
select_1_recording(duplica_2)
# Out:
#      patient_id select audible   outcome
# 0          2530     PV      PV  Abnormal
# 1          9979     AV      TV  Abnormal
# 3         13918     PV      TV  Abnormal
# 4         14241     MV      PV  Abnormal
# 5         14998     PV      PV  Abnormal
# ..          ...    ...     ...       ...
# 934       85337     PV      PV    Normal
# 935       85338     MV      MV    Normal
# 937       85340     TV      TV    Normal
# 938       85341     MV      MV    Normal
# 939       85343     PV      TV  Abnormal
#
# [521 rows x 4 columns]

# %%
wave_file='../raw_data/1.0.3/audio_raw/2530_AV.wav'

# %%
wave_file.rsplit('.wav')[0].split('/')[-1]
# Out:
# '2530_AV'
